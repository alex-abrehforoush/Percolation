# %%
import numpy as np
import pandas as pd

# %%
data = {
    'L/2': [],
    'density': [],
    'probability_of_spread': [],
    'south_wind_speed': [],
    'west_wind_speed': [],
    'big-jumps': [],
    'percentage-burned': []
}

df = pd.DataFrame(data)
print(df)
# Out:
# Empty DataFrame
# Columns: [L/2, density, probability_of_spread, south_wind_speed, west_wind_speed, big-jumps, percentage-burned]
# Index: []

# %%
# Create a DataFrame with the repeated values
new_data = {'L/2': [150] * 10,
            'density': [0.6] * 10,
            'probability_of_spread': [1] * 10,
            'south_wind_speed': [0] * 10,
            'west_wind_speed': [0] * 10,
            'big-jumps': [False] * 10,
            'percentage-burned': [75, 24.4, 71.6, 79.3, 66.9, 63, 47.6, 66.4, 71.2, 78.9]}

new_df = pd.DataFrame(new_data)

# Append the new DataFrame to the existing DataFrame
df = df.append(new_df, ignore_index=True)

# %%
df
# Out:
#      L/2  density  probability_of_spread  south_wind_speed  west_wind_speed  \
# 0  150.0      0.6                    1.0               0.0              0.0
# 1  150.0      0.6                    1.0               0.0              0.0
# 2  150.0      0.6                    1.0               0.0              0.0
# 3  150.0      0.6                    1.0               0.0              0.0
# 4  150.0      0.6                    1.0               0.0              0.0
# 5  150.0      0.6                    1.0               0.0              0.0
# 6  150.0      0.6                    1.0               0.0              0.0
# 7  150.0      0.6                    1.0               0.0              0.0
# 8  150.0      0.6                    1.0               0.0              0.0
# 9  150.0      0.6                    1.0               0.0              0.0
#
#    big-jumps  percentage-burned
# 0        0.0               75.0
# 1        0.0               24.4
# 2        0.0               71.6
# ...

# %%
# Create a DataFrame with the repeated values
new_data = {'L/2': [250] * 10,
            'density': [0.6] * 10,
            'probability_of_spread': [1] * 10,
            'south_wind_speed': [0] * 10,
            'west_wind_speed': [0] * 10,
            'big-jumps': [False] * 10,
            'percentage-burned': [48.7, 76.7, 75.8, 70.5, 67.8, 21.5, 68, 70.2, 73.7, 67.6]}

new_df = pd.DataFrame(new_data)

# Append the new DataFrame to the existing DataFrame
df = df.append(new_df, ignore_index=True)

# %%
# Create a DataFrame with the repeated values
new_data = {'L/2': [350] * 10,
            'density': [0.6] * 10,
            'probability_of_spread': [1] * 10,
            'south_wind_speed': [0] * 10,
            'west_wind_speed': [0] * 10,
            'big-jumps': [False] * 10,
            'percentage-burned': [75.3, 68.9, 68.7, 62.6, 70, 75.3, 72.6, 63.7, 17.4, 61.4]}

new_df = pd.DataFrame(new_data)

# Append the new DataFrame to the existing DataFrame
df = df.append(new_df, ignore_index=True)

# %%
# Create a DataFrame with the repeated values
new_data = {'L/2': [450] * 10,
            'density': [0.6] * 10,
            'probability_of_spread': [1] * 10,
            'south_wind_speed': [0] * 10,
            'west_wind_speed': [0] * 10,
            'big-jumps': [False] * 10,
            'percentage-burned': [73.9, 71.2, 73, 73.5, 71.2, 73.9, 71.2, 73.6, 71, 72.8]}

new_df = pd.DataFrame(new_data)

# Append the new DataFrame to the existing DataFrame
df = df.append(new_df, ignore_index=True)

# %%
# Create a DataFrame with the repeated values
new_data = {'L/2': [200] * 10,
            'density': [0.6] * 10,
            'probability_of_spread': [1] * 10,
            'south_wind_speed': [0] * 10,
            'west_wind_speed': [0] * 10,
            'big-jumps': [False] * 10,
            'percentage-burned': [58.3,78.3,78.4,72.5,76.5,64.6,76.6,72.4,74.3,25.4]}

new_df = pd.DataFrame(new_data)

# Append the new DataFrame to the existing DataFrame
df = df.append(new_df, ignore_index=True)

# %%
# Create a DataFrame with the repeated values
new_data = {'L/2': [300] * 10,
            'density': [0.6] * 10,
            'probability_of_spread': [1] * 10,
            'south_wind_speed': [0] * 10,
            'west_wind_speed': [0] * 10,
            'big-jumps': [False] * 10,
            'percentage-burned': [63.3,72.7,67.8,74.7,76.5,70.5,68.2,66.3, 72.4,70.1]}

new_df = pd.DataFrame(new_data)

# Append the new DataFrame to the existing DataFrame
df = df.append(new_df, ignore_index=True)

# %%
# Create a DataFrame with the repeated values
new_data = {'L/2': [400] * 10,
            'density': [0.6] * 10,
            'probability_of_spread': [1] * 10,
            'south_wind_speed': [0] * 10,
            'west_wind_speed': [0] * 10,
            'big-jumps': [False] * 10,
            'percentage-burned': [72.3, 73.3, 68.1, 67.2, 74.4, 71.3, 72.7, 76.2, 70.9, 64.5]}

new_df = pd.DataFrame(new_data)

# Append the new DataFrame to the existing DataFrame
df = df.append(new_df, ignore_index=True)

# %%
# Create a DataFrame with the repeated values
new_data = {'L/2': [500] * 10,
            'density': [0.6] * 10,
            'probability_of_spread': [1] * 10,
            'south_wind_speed': [0] * 10,
            'west_wind_speed': [0] * 10,
            'big-jumps': [False] * 10,
            'percentage-burned': [69.3, 65.6, 72.9, 76.3, 76.2, 66.3, 73.7, 78.4, 75.5, 74 ]}

new_df = pd.DataFrame(new_data)

# Append the new DataFrame to the existing DataFrame
df = df.append(new_df, ignore_index=True)

# %%
# Create a DataFrame with the repeated values
new_data = {'L/2': [150] * 10,
            'density': [0.5] * 10,
            'probability_of_spread': [1] * 10,
            'south_wind_speed': [0] * 10,
            'west_wind_speed': [0] * 10,
            'big-jumps': [False] * 10,
            'percentage-burned': [2.4, 2.4, 2.6, 2, 2.7, 3.1, 2.6, 2.5, 2.5, 2.9]}

new_df = pd.DataFrame(new_data)

# Append the new DataFrame to the existing DataFrame
df = df.append(new_df, ignore_index=True)

# %%
# Create a DataFrame with the repeated values
new_data = {'L/2': [200] * 10,
            'density': [0.5] * 10,
            'probability_of_spread': [1] * 10,
            'south_wind_speed': [0] * 10,
            'west_wind_speed': [0] * 10,
            'big-jumps': [False] * 10,
            'percentage-burned': [2.3, 2.4, 2.3, 1.9, 2.2, 2.3, 1.9, 2.1, 2.3, 2.2]}

new_df = pd.DataFrame(new_data)

# Append the new DataFrame to the existing DataFrame
df = df.append(new_df, ignore_index=True)

# %%
# Create a DataFrame with the repeated values
new_data = {'L/2': [250] * 10,
            'density': [0.5] * 10,
            'probability_of_spread': [1] * 10,
            'south_wind_speed': [0] * 10,
            'west_wind_speed': [0] * 10,
            'big-jumps': [False] * 10,
            'percentage-burned': [1.8, 1.5, 1.5, 1.4, 1.4, 1.9, 1.4, 1.5, 1.4, 1.7]}

new_df = pd.DataFrame(new_data)

# Append the new DataFrame to the existing DataFrame
df = df.append(new_df, ignore_index=True)

# %%
# Create a DataFrame with the repeated values
new_data = {'L/2': [300] * 10,
            'density': [0.5] * 10,
            'probability_of_spread': [1] * 10,
            'south_wind_speed': [0] * 10,
            'west_wind_speed': [0] * 10,
            'big-jumps': [False] * 10,
            'percentage-burned': [1.2, 1.5, 1.4, 1.4, 1.2, 1.4, 1.2, 1.3, 1.2, 1.4]}

new_df = pd.DataFrame(new_data)

# Append the new DataFrame to the existing DataFrame
df = df.append(new_df, ignore_index=True)

# %%
# Create a DataFrame with the repeated values
new_data = {'L/2': [350] * 10,
            'density': [0.5] * 10,
            'probability_of_spread': [1] * 10,
            'south_wind_speed': [0] * 10,
            'west_wind_speed': [0] * 10,
            'big-jumps': [False] * 10,
            'percentage-burned': [1.4, 1.3, 1.2, 1.1, 1.1, 1.3, 0.9, 0.9, 1.1, 1.1]}

new_df = pd.DataFrame(new_data)

# Append the new DataFrame to the existing DataFrame
df = df.append(new_df, ignore_index=True)

# %%
# Create a DataFrame with the repeated values
new_data = {'L/2': [400] * 10,
            'density': [0.5] * 10,
            'probability_of_spread': [1] * 10,
            'south_wind_speed': [0] * 10,
            'west_wind_speed': [0] * 10,
            'big-jumps': [False] * 10,
            'percentage-burned': [1, 1.1, 1, 1, 1.1, 1, 0.9, 1.1, 1, 1.1]}

new_df = pd.DataFrame(new_data)

# Append the new DataFrame to the existing DataFrame
df = df.append(new_df, ignore_index=True)

# %%
# Create a DataFrame with the repeated values
new_data = {'L/2': [450] * 10,
            'density': [0.5] * 10,
            'probability_of_spread': [1] * 10,
            'south_wind_speed': [0] * 10,
            'west_wind_speed': [0] * 10,
            'big-jumps': [False] * 10,
            'percentage-burned': [0.2, 0.2, 0.9, 0.9, 0.9, 0.8, 0.8, 0.9, 0.9, 0.8]}

new_df = pd.DataFrame(new_data)

# Append the new DataFrame to the existing DataFrame
df = df.append(new_df, ignore_index=True)

# %%
# Create a DataFrame with the repeated values
new_data = {'L/2': [500] * 10,
            'density': [0.5] * 10,
            'probability_of_spread': [1] * 10,
            'south_wind_speed': [0] * 10,
            'west_wind_speed': [0] * 10,
            'big-jumps': [False] * 10,
            'percentage-burned': [0.8, 0.7, 0.8, 0.9, 0.8, 0.8, 0.8, 0.9, 0.8, 0.9]}

new_df = pd.DataFrame(new_data)

# Append the new DataFrame to the existing DataFrame
df = df.append(new_df, ignore_index=True)

# %%
# Create a DataFrame with the repeated values
new_data = {'L/2': [150] * 10,
            'density': [0.63] * 10,
            'probability_of_spread': [1] * 10,
            'south_wind_speed': [0] * 10,
            'west_wind_speed': [0] * 10,
            'big-jumps': [False] * 10,
            'percentage-burned': [90.3, 91.7, 92.4, 92.1, 91.3, 91.5, 85.8, 91.6, 90.2, 89.9]}

new_df = pd.DataFrame(new_data)

# Append the new DataFrame to the existing DataFrame
df = df.append(new_df, ignore_index=True)

# %%
# Create a DataFrame with the repeated values
new_data = {'L/2': [200] * 10,
            'density': [0.63] * 10,
            'probability_of_spread': [1] * 10,
            'south_wind_speed': [0] * 10,
            'west_wind_speed': [0] * 10,
            'big-jumps': [False] * 10,
            'percentage-burned': [92.5, 89.9, 92.1, 91.6, 91.1, 91.9, 91.6, 90.5, 90.4, 91.1]}

new_df = pd.DataFrame(new_data)

# Append the new DataFrame to the existing DataFrame
df = df.append(new_df, ignore_index=True)

# %%
# Create a DataFrame with the repeated values
new_data = {'L/2': [250] * 10,
            'density': [0.63] * 10,
            'probability_of_spread': [1] * 10,
            'south_wind_speed': [0] * 10,
            'west_wind_speed': [0] * 10,
            'big-jumps': [False] * 10,
            'percentage-burned': [91.6, 91.9, 90.7, 90.8, 91.3, 91.1, 91.6, 92.3, 91.6, 91.5]}

new_df = pd.DataFrame(new_data)

# Append the new DataFrame to the existing DataFrame
df = df.append(new_df, ignore_index=True)

# %%
# Create a DataFrame with the repeated values
new_data = {'L/2': [300] * 10,
            'density': [0.63] * 10,
            'probability_of_spread': [1] * 10,
            'south_wind_speed': [0] * 10,
            'west_wind_speed': [0] * 10,
            'big-jumps': [False] * 10,
            'percentage-burned': [91.8, 91.6, 92, 91.7, ]}

new_df = pd.DataFrame(new_data)

# Append the new DataFrame to the existing DataFrame
df = df.append(new_df, ignore_index=True)

# %% [markdown]
# # new settlements

# %%
# Create a DataFrame with the repeated values
n = 9
new_data = {'L/2': [450] * n,
            'density': [0.1 * i for i in range(1, 10)],
            'probability_of_spread': [1] * n,
            'south_wind_speed': [0] * n,
            'west_wind_speed': [0] * n,
            'big-jumps': [False] * n,
            'percentage-burned': [1.2, 0.7, 0.6, 0.6, 0.9, 74, 98.5, 99.9, 100]}

new_df = pd.DataFrame(new_data)

# Append the new DataFrame to the existing DataFrame
df = df.append(new_df, ignore_index=True)

# Create a DataFrame with the repeated values
n = 9
new_data = {'L/2': [450] * n,
            'density': [0.1 * i for i in range(1, 10)],
            'probability_of_spread': [1] * n,
            'south_wind_speed': [0] * n,
            'west_wind_speed': [0] * n,
            'big-jumps': [False] * n,
            'percentage-burned': [1.2, 0.7, 0.6, 0.6, 1, 70.5, 98.4, 99.9, 100]}

new_df = pd.DataFrame(new_data)

# Append the new DataFrame to the existing DataFrame
df = df.append(new_df, ignore_index=True)

# Create a DataFrame with the repeated values
n = 9
new_data = {'L/2': [450] * n,
            'density': [0.1 * i for i in range(1, 10)],
            'probability_of_spread': [1] * n,
            'south_wind_speed': [0] * n,
            'west_wind_speed': [0] * n,
            'big-jumps': [False] * n,
            'percentage-burned': [1.2, 0.7, 0.6, 0.6, 0.9, 77.1, 98.3, 99.9, 100]}

new_df = pd.DataFrame(new_data)

# Append the new DataFrame to the existing DataFrame
df = df.append(new_df, ignore_index=True)









# Create a DataFrame with the repeated values
n = 9
new_data = {'L/2': [450] * n,
            'density': [0.1 * i for i in range(1, 10)],
            'probability_of_spread': [1] * n,
            'south_wind_speed': [0] * n,
            'west_wind_speed': [10] * n,
            'big-jumps': [False] * n,
            'percentage-burned': [1.2, 0.7, 0.6, 0.6, 1, 49, 97.7, 99.8, ]}

new_df = pd.DataFrame(new_data)

# Append the new DataFrame to the existing DataFrame
df = df.append(new_df, ignore_index=True)

# Create a DataFrame with the repeated values
n = 9
new_data = {'L/2': [450] * n,
            'density': [0.1 * i for i in range(1, 10)],
            'probability_of_spread': [1] * n,
            'south_wind_speed': [0] * n,
            'west_wind_speed': [10] * n,
            'big-jumps': [False] * n,
            'percentage-burned': [1.2, 0.7, 0.5, 0.6, 0.9, 60.7, 97.8, 99.8]}

new_df = pd.DataFrame(new_data)

# Append the new DataFrame to the existing DataFrame
df = df.append(new_df, ignore_index=True)

# Create a DataFrame with the repeated values
n = 9
new_data = {'L/2': [450] * n,
            'density': [0.1 * i for i in range(1, 10)],
            'probability_of_spread': [1] * n,
            'south_wind_speed': [0] * n,
            'west_wind_speed': [10] * n,
            'big-jumps': [False] * n,
            'percentage-burned': [1.2, 0.7, 0.6, 0.6, 0.8, 49.1, 97.9, 99.8]}

new_df = pd.DataFrame(new_data)

# Append the new DataFrame to the existing DataFrame
df = df.append(new_df, ignore_index=True)
